# %%
# !pip install jupyter_contrib_nbextensions && jupyter contrib nbextensions install
# Out:
# ...
# [I 02:06:19 InstallContribNbextensionsApp] jupyter contrib nbextension install
# [I 02:06:19 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 02:06:19 InstallContribNbextensionsApp] Installing /Users/dk/opt/anaconda3/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 02:06:19 InstallContribNbextensionsApp] Making directory: /usr/local/share/jupyter/nbextensions/rubberband/
# [I 02:06:19 InstallContribNbextensionsApp] Copying: /Users/dk/opt/anaconda3/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/icon.png -> /usr/local/share/jupyter/nbextensions/rubberband/icon.png
# [I 02:06:19 InstallContribNbextensionsApp] Copying: /Users/dk/opt/anaconda3/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/main.css -> /usr/local/share/jupyter/nbextensions/rubberband/main.css
# ...
